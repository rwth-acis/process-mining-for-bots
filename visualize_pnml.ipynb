# %%
import pm4py

# %% [markdown]
# # Visualize a pnml file

# %%
net, initial_marking, final_marking = pm4py.read_pnml("test_model.pnml")
print(net)
gviz = pm4py.view_petri_net(net, initial_marking, final_marking)
# Out:
# places: [ 155b06c1081b98b25f7d3bd7, 203ece0fc479006a0100da02, 230a964635d0d65be8adf007, 6010d845b63a4cc23f60ebd0, 6101bb904b6349c1503cfe98, 61844f258e2683e1b3ce657e, 82c78962f6861625e49a1514, c7fa669d6c437ce2e38227ec, c979f107df5206374259164e, d3261f4fead10d510893de7b, d63fc2c95d6ebb9f32d62109, d655de4e1e24786d6914f480, eb266988105da55ab1dbfb62, ef006227047ea862daeef74c, ef36e373947bd046b241afb6, f3476d06d66500acfe0302d2, initial_marking, sink0 ]
# transitions: [ (0d6daa47e7c34171bba39dbd, 'rejection'), (117e0d66e833fb189e661891, 'help'), (260085832f8353a7941f715b, 'getMenu'), (2737c217b4ca167946a11531, 'listMensas'), (2cf567110bae35efe71a5cdf, 'greeting'), (3b995f08d360475619d5dead, 'menu'), (634a4745877740ed163a77fa, 'rejection'), (7169854c636b80c0a1dd7639, 'prepareReview'), (79552d31107b16eafdcb5fe3, 'prepareReview'), (8631a4c087becb9236bcafbb, 'chooseMensaAndMeal'), (9b1dbda718ab29d02cf45d48, 'rejection'), (9df99e13096da83d093358fb, 'confirmation'), (a591cae876337f97bc28a95e, 'thanks'), (a913d82e77b1ec8edc5b566a, None), (b3bb240b54166af91c94ce4b, 'confirmation'), (b83a85b73e0b1ed74ed0091e, 'startReview'), (d94ff20cab73cf98782a9efc, 'submitReview'), (df08bdf6da892e42169acac2, 'default'), (df17b98b9ca57517d5eb134c, None), (f8f8142fd272fb35e933c7d4, 'stars,number_selection'), (ff9801f80454b4dbcedd4737, 'sad') ]
# arcs: [ (0d6daa47e7c34171bba39dbd, 'rejection')->sink0, (117e0d66e833fb189e661891, 'help')->sink0, (260085832f8353a7941f715b, 'getMenu')->sink0, (2737c217b4ca167946a11531, 'listMensas')->155b06c1081b98b25f7d3bd7, (2cf567110bae35efe71a5cdf, 'greeting')->sink0, (3b995f08d360475619d5dead, 'menu')->203ece0fc479006a0100da02, (634a4745877740ed163a77fa, 'rejection')->6101bb904b6349c1503cfe98, (634a4745877740ed163a77fa, 'rejection')->61844f258e2683e1b3ce657e, (7169854c636b80c0a1dd7639, 'prepareReview')->sink0, (79552d31107b16eafdcb5fe3, 'prepareReview')->sink0, (8631a4c087becb9236bcafbb, 'chooseMensaAndMeal')->230a964635d0d65be8adf007, (8631a4c087becb9236bcafbb, 'chooseMensaAndMeal')->6010d845b63a4cc23f60ebd0, (8631a4c087becb9236bcafbb, 'chooseMensaAndMeal')->c7fa669d6c437ce2e38227ec, (9b1dbda718ab29d02cf45d48, 'rejection')->ef36e373947bd046b241afb6, (9df99e13096da83d093358fb, 'confirmation')->d63fc2c95d6ebb9f32d62109, (a591cae876337f97bc28a95e, 'thanks')->sink0, (a913d82e77b1ec8edc5b566a, None)->c979f107df5206374259164e, (b3bb240b54166af91c94ce4b, 'confirmation')->eb266988105da55ab1dbfb62, (b83a85b73e0b1ed74ed0091e, 'startReview')->d655de4e1e24786d6914f480, (d94ff20cab73cf98782a9efc, 'submitReview')->sink0, (df08bdf6da892e42169acac2, 'default')->sink0, (df17b98b9ca57517d5eb134c, None)->82c78962f6861625e49a1514, (df17b98b9ca57517d5eb134c, None)->f3476d06d66500acfe0302d2, (f8f8142fd272fb35e933c7d4, 'stars,number_selection')->d3261f4fead10d510893de7b, (f8f8142fd272fb35e933c7d4, 'stars,number_selection')->ef006227047ea862daeef74c, (ff9801f80454b4dbcedd4737, 'sad')->sink0, 155b06c1081b98b25f7d3bd7->(260085832f8353a7941f715b, 'getMenu'), 203ece0fc479006a0100da02->(260085832f8353a7941f715b, 'getMenu'), 230a964635d0d65be8adf007->(634a4745877740ed163a77fa, 'rejection'), 6010d845b63a4cc23f60ebd0->(b3bb240b54166af91c94ce4b, 'confirmation'), 6101bb904b6349c1503cfe98->(9df99e13096da83d093358fb, 'confirmation'), 61844f258e2683e1b3ce657e->(0d6daa47e7c34171bba39dbd, 'rejection'), 82c78962f6861625e49a1514->(9b1dbda718ab29d02cf45d48, 'rejection'), c7fa669d6c437ce2e38227ec->(79552d31107b16eafdcb5fe3, 'prepareReview'), c979f107df5206374259164e->(d94ff20cab73cf98782a9efc, 'submitReview'), d3261f4fead10d510893de7b->(df17b98b9ca57517d5eb134c, None), d63fc2c95d6ebb9f32d62109->(8631a4c087becb9236bcafbb, 'chooseMensaAndMeal'), d655de4e1e24786d6914f480->(8631a4c087becb9236bcafbb, 'chooseMensaAndMeal'), eb266988105da55ab1dbfb62->(f8f8142fd272fb35e933c7d4, 'stars,number_selection'), ef006227047ea862daeef74c->(7169854c636b80c0a1dd7639, 'prepareReview'), ef36e373947bd046b241afb6->(d94ff20cab73cf98782a9efc, 'submitReview'), f3476d06d66500acfe0302d2->(a913d82e77b1ec8edc5b566a, None), initial_marking->(117e0d66e833fb189e661891, 'help'), initial_marking->(2737c217b4ca167946a11531, 'listMensas'), initial_marking->(2cf567110bae35efe71a5cdf, 'greeting'), initial_marking->(3b995f08d360475619d5dead, 'menu'), initial_marking->(a591cae876337f97bc28a95e, 'thanks'), initial_marking->(b83a85b73e0b1ed74ed0091e, 'startReview'), initial_marking->(df08bdf6da892e42169acac2, 'default'), initial_marking->(ff9801f80454b4dbcedd4737, 'sad') ]
