# %%
import pm4py

# %% [markdown]
# # Visualize a pnml file

# %%
net, initial_marking, final_marking = pm4py.read_pnml("test_model.pnml")
print(net)
gviz = pm4py.view_petri_net(net, initial_marking, final_marking)
# Out:
# places: [ 0d6daa47e7c34171bba39dbd, 260085832f8353a7941f715b, 2737c217b4ca167946a11531, 3b995f08d360475619d5dead, 634a4745877740ed163a77fa, 7169854c636b80c0a1dd7639, 79552d31107b16eafdcb5fe3, 8631a4c087becb9236bcafbb, 9b1dbda718ab29d02cf45d48, 9df99e13096da83d093358fb, a913d82e77b1ec8edc5b566a, b3bb240b54166af91c94ce4b, b83a85b73e0b1ed74ed0091e, d94ff20cab73cf98782a9efc, f8f8142fd272fb35e933c7d4, sink, source ]
# ...
